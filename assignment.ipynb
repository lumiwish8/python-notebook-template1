# %% [markdown]
# # 과제 1: 기초 통계 함수
# 아래 함수들을 완성하세요. pass를 지우고 코드를 작성하세요.

# %%
import numpy as np

# 문제 1 (40점): 평균과 표준편차를 반환하는 함수
def calculate_stats(data):
    pass

# 문제 2 (60점): 베이즈 사후확률 계산 함수
def bayes_posterior(prior, likelihood, evidence):
    pass

# %%
# 간단한 자체 테스트
print(calculate_stats([1, 2, 3, 4, 5]))  # 기대값: (3.0, 1.4142...)
print(bayes_posterior(0.01, 0.9, 0.05))   # 기대값: 0.18
# Out:
# None
# None
